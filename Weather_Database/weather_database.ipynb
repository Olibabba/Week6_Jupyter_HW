# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_key
from datetime import datetime
import time
# from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# unzip the coordinates into a list
coordinates = list(lat_lngs)

# %%
# convert lat and longs to city names
city_names = []
country_names = []

for x in coordinates:
    this_city = citipy.nearest_city(x[0], x[1]).city_name
    this_country = citipy.nearest_city(x[0], x[1]).country_code
    if this_city not in city_names:
        city_names.append(this_city)
        country_names.append(this_country)
len(city_names)
# Out:
# 754

# %%
url = f'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_key}'

# %%
# ex_url = url + "&q=" + "canavieiras"
# ex_weather = requests.get(ex_url).json()
# ex_weather

# %%
# ex_country = (ex_weather['sys']['country'])
# ex_country

# %%
# des = (ex_weather['weather'][0]['description'])
# des

# %%
# empty list to hold weather data
city_data = []

#print log beginning
print("Beginning Data Retrieval   ")
print("---------------------------")

#create counters
record_count = 1
set_count = 1

# loop through all cities
for i, city in enumerate(city_names):
    
    # group cities in sets of 50 for logging and rest for one minute to comply with api rules
    if( i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log url, record, and set numbers, and city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #increase record
    record_count += 1
    
    try:
        #parse the json
        city_weather = requests.get(city_url).json()

        #grab the data
        country = (city_weather['sys']['country'])
        lat = (city_weather['coord']['lat'])
        lng = (city_weather['coord']['lon'])
        max_temp = (city_weather['main']['temp_max'])
        min_temp = (city_weather['main']['temp_min'])
        humidity = (city_weather['main']['humidity'])
        clouds = (city_weather['clouds']['all'])
        wind = (city_weather['wind']['speed'])
        description = (city_weather['weather'][0]['description'])

        #convert date to iso
        date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%y-%m-%d %H:%M:%S')

        #add data to city_data list
        city_data.append({'City': city.title(),
                           'Country': country,
                           "Date": date,
                           "Lat": lat,
                           "Lng": lng,
                           "Max Temp": max_temp,
                           "Min Temp": min_temp,
                           "Humidity": humidity,
                           "Cloudiness": clouds,
                           "Wind Speed": wind,
                           "Current Description": description})
# error handling, skip city
    except:
        print(f"City not found. Skipping...")
        pass

#data loading complete message
print("---------------------------")
print("Data Retrieval Complete    ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | tiruchchendur
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | alofi
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | kaitangata
# Processing Record 7 of Set 1 | port hardy
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | kajaani
# Processing Record 10 of Set 1 | anan
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | mapiripan
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | berlevag
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | buala
# Processing Record 25 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 26 of Set 1 | yoichi
# Processing Record 27 of Set 1 | iskateley
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | kyabe
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | qunduz
# Processing Record 34 of Set 1 | portland
# Processing Record 35 of Set 1 | pedra azul
# Processing Record 36 of Set 1 | matagami
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | batemans bay
# Processing Record 40 of Set 1 | strezhevoy
# Processing Record 41 of Set 1 | san vicente
# Processing Record 42 of Set 1 | warrington
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | caravelas
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | muroto
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 2 | chigorodo
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | pangnirtung
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | antofagasta
# Processing Record 8 of Set 2 | santiago del estero
# Processing Record 9 of Set 2 | wamba
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | lavrentiya
# Processing Record 12 of Set 2 | quelimane
# Processing Record 13 of Set 2 | verkhoyansk
# Processing Record 14 of Set 2 | manakara
# Processing Record 15 of Set 2 | shelburne
# Processing Record 16 of Set 2 | epsom
# Processing Record 17 of Set 2 | korgen
# Processing Record 18 of Set 2 | pacific grove
# Processing Record 19 of Set 2 | manokwari
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | gornozavodsk
# Processing Record 23 of Set 2 | lata
# Processing Record 24 of Set 2 | san jose
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | yamada
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | faya
# Processing Record 30 of Set 2 | redmond
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | boa viagem
# Processing Record 33 of Set 2 | valley city
# Processing Record 34 of Set 2 | richards bay
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | doha
# Processing Record 37 of Set 2 | samoded
# Processing Record 38 of Set 2 | hailar
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | kautokeino
# Processing Record 41 of Set 2 | gladstone
# Processing Record 42 of Set 2 | vung tau
# Processing Record 43 of Set 2 | port blair
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | luoyang
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | harer
# Processing Record 1 of Set 3 | nishihara
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | arcata
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | brae
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | eirunepe
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | coxim
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | severo-yeniseyskiy
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | khash
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | hobart
# Processing Record 19 of Set 3 | husavik
# Processing Record 20 of Set 3 | sovetskiy
# Processing Record 21 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 3 | fukue
# Processing Record 23 of Set 3 | itoman
# Processing Record 24 of Set 3 | klaksvik
# Processing Record 25 of Set 3 | sturgeon falls
# Processing Record 26 of Set 3 | cabedelo
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | soyo
# Processing Record 30 of Set 3 | sechenovo
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | hay river
# Processing Record 34 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 3 | krasnoturansk
# Processing Record 36 of Set 3 | dangriga
# Processing Record 37 of Set 3 | beringovskiy
# Processing Record 38 of Set 3 | pochutla
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | ankang
# Processing Record 41 of Set 3 | kanniyakumari
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | kati
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 3 | gizo
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | jardim
# Processing Record 49 of Set 3 | baculin
# Processing Record 50 of Set 3 | payo
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | nantucket
# Processing Record 3 of Set 4 | yago
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | fort nelson
# Processing Record 6 of Set 4 | sola
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | dharchula
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | keflavik
# Processing Record 11 of Set 4 | paamiut
# Processing Record 12 of Set 4 | wattegama
# Processing Record 13 of Set 4 | diamantino
# Processing Record 14 of Set 4 | sur
# Processing Record 15 of Set 4 | ganzhou
# Processing Record 16 of Set 4 | havoysund
# Processing Record 17 of Set 4 | belyy yar
# Processing Record 18 of Set 4 | codrington
# Processing Record 19 of Set 4 | ovsyanka
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | sao borja
# Processing Record 24 of Set 4 | tupiza
# Processing Record 25 of Set 4 | zhanaozen
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | commerce
# Processing Record 29 of Set 4 | cockburn town
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | mozarlandia
# Processing Record 32 of Set 4 | tura
# Processing Record 33 of Set 4 | atlanta
# Processing Record 34 of Set 4 | koping
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | bandarbeyla
# Processing Record 37 of Set 4 | along
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | gondanglegi
# Processing Record 40 of Set 4 | taoudenni
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | mandera
# Processing Record 45 of Set 4 | dikson
# Processing Record 46 of Set 4 | sigulda
# Processing Record 47 of Set 4 | villa carlos paz
# Processing Record 48 of Set 4 | hermanus
# Processing Record 49 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 4 | emerald
# Processing Record 1 of Set 5 | sarangani
# Processing Record 2 of Set 5 | chingirlau
# Processing Record 3 of Set 5 | poum
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | honiara
# Processing Record 6 of Set 5 | cidreira
# Processing Record 7 of Set 5 | kolpny
# Processing Record 8 of Set 5 | keetmanshoop
# Processing Record 9 of Set 5 | kozhevnikovo
# Processing Record 10 of Set 5 | russell
# Processing Record 11 of Set 5 | marsabit
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | sungaipenuh
# Processing Record 14 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 5 | abengourou
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | mazagao
# Processing Record 18 of Set 5 | parit buntar
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | ginir
# Processing Record 23 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 5 | san juan
# Processing Record 25 of Set 5 | domoni
# Processing Record 26 of Set 5 | tinskoy
# Processing Record 27 of Set 5 | port elizabeth
# Processing Record 28 of Set 5 | necochea
# Processing Record 29 of Set 5 | cayhagan
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | port hedland
# Processing Record 32 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 5 | srikakulam
# Processing Record 34 of Set 5 | tiksi
# Processing Record 35 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 5 | bambanglipuro
# Processing Record 37 of Set 5 | mahibadhoo
# Processing Record 38 of Set 5 | trairi
# Processing Record 39 of Set 5 | ahipara
# Processing Record 40 of Set 5 | kunming
# Processing Record 41 of Set 5 | arraial do cabo
# Processing Record 42 of Set 5 | killin
# Processing Record 43 of Set 5 | hammerfest
# Processing Record 44 of Set 5 | palmer
# Processing Record 45 of Set 5 | yar-sale
# Processing Record 46 of Set 5 | merrill
# Processing Record 47 of Set 5 | kulu
# Processing Record 48 of Set 5 | noshiro
# Processing Record 49 of Set 5 | pevek
# Processing Record 50 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 1 of Set 6 | nogliki
# Processing Record 2 of Set 6 | davila
# Processing Record 3 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 6 | namatanai
# Processing Record 5 of Set 6 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 6 of Set 6 | kodiak
# Processing Record 7 of Set 6 | puerto lopez
# Processing Record 8 of Set 6 | ondjiva
# Processing Record 9 of Set 6 | dingle
# Processing Record 10 of Set 6 | roald
# Processing Record 11 of Set 6 | colac
# Processing Record 12 of Set 6 | dawei
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | koungou
# Processing Record 15 of Set 6 | harper
# Processing Record 16 of Set 6 | labuhan
# Processing Record 17 of Set 6 | san carlos de bariloche
# Processing Record 18 of Set 6 | qeshm
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint-joseph
# Processing Record 21 of Set 6 | okato
# Processing Record 22 of Set 6 | abu dhabi
# Processing Record 23 of Set 6 | comodoro rivadavia
# Processing Record 24 of Set 6 | alihe
# Processing Record 25 of Set 6 | yulara
# Processing Record 26 of Set 6 | tazovskiy
# Processing Record 27 of Set 6 | vikhorevka
# Processing Record 28 of Set 6 | stephenville
# Processing Record 29 of Set 6 | khandbari
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | thabazimbi
# Processing Record 32 of Set 6 | biltine
# Processing Record 33 of Set 6 | kibala
# Processing Record 34 of Set 6 | clarksburg
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | meridian
# Processing Record 37 of Set 6 | san andres
# Processing Record 38 of Set 6 | bontang
# Processing Record 39 of Set 6 | puerto ayacucho
# Processing Record 40 of Set 6 | san-pedro
# Processing Record 41 of Set 6 | gornyy
# Processing Record 42 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 6 | gonaives
# Processing Record 44 of Set 6 | shenjiamen
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | shiliguri
# Processing Record 47 of Set 6 | colares
# Processing Record 48 of Set 6 | haines junction
# Processing Record 49 of Set 6 | havelock
# Processing Record 50 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 7 | mount gambier
# Processing Record 3 of Set 7 | piterka
# Processing Record 4 of Set 7 | elko
# Processing Record 5 of Set 7 | lima
# Processing Record 6 of Set 7 | kerman
# Processing Record 7 of Set 7 | krabi
# Processing Record 8 of Set 7 | vozrozhdeniye
# Processing Record 9 of Set 7 | urtaaul
# City not found. Skipping...
# Processing Record 10 of Set 7 | siocon
# Processing Record 11 of Set 7 | puerto escondido
# Processing Record 12 of Set 7 | luderitz
# Processing Record 13 of Set 7 | abbotsford
# Processing Record 14 of Set 7 | margate
# Processing Record 15 of Set 7 | kavaratti
# Processing Record 16 of Set 7 | narsaq
# Processing Record 17 of Set 7 | farah
# Processing Record 18 of Set 7 | bambous virieux
# Processing Record 19 of Set 7 | middleton
# Processing Record 20 of Set 7 | gangapur
# Processing Record 21 of Set 7 | waipawa
# Processing Record 22 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 23 of Set 7 | humaita
# Processing Record 24 of Set 7 | auckland
# Processing Record 25 of Set 7 | gawler
# Processing Record 26 of Set 7 | sambava
# Processing Record 27 of Set 7 | nhamunda
# Processing Record 28 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 29 of Set 7 | gumla
# Processing Record 30 of Set 7 | hobyo
# Processing Record 31 of Set 7 | uppsala
# Processing Record 32 of Set 7 | maragogi
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | turhal
# Processing Record 35 of Set 7 | grand gaube
# Processing Record 36 of Set 7 | lompoc
# Processing Record 37 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 7 | manthani
# Processing Record 39 of Set 7 | bac can
# City not found. Skipping...
# Processing Record 40 of Set 7 | whitehorse
# Processing Record 41 of Set 7 | tautira
# Processing Record 42 of Set 7 | gat
# Processing Record 43 of Set 7 | uelzen
# Processing Record 44 of Set 7 | plettenberg bay
# Processing Record 45 of Set 7 | kahului
# Processing Record 46 of Set 7 | kosovska mitrovica
# Processing Record 47 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 7 | zafarabad
# Processing Record 49 of Set 7 | jumla
# Processing Record 50 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 8 | peniche
# Processing Record 2 of Set 8 | thinadhoo
# Processing Record 3 of Set 8 | paidha
# Processing Record 4 of Set 8 | vardo
# Processing Record 5 of Set 8 | ternate
# Processing Record 6 of Set 8 | taraz
# Processing Record 7 of Set 8 | jalu
# Processing Record 8 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 8 | duncan
# Processing Record 10 of Set 8 | bereda
# Processing Record 11 of Set 8 | ngorongoro
# Processing Record 12 of Set 8 | kupang
# Processing Record 13 of Set 8 | torbay
# Processing Record 14 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 8 | albi
# Processing Record 16 of Set 8 | westport
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | yanam
# Processing Record 19 of Set 8 | bilma
# Processing Record 20 of Set 8 | praia da vitoria
# Processing Record 21 of Set 8 | vila
# Processing Record 22 of Set 8 | illintsi
# Processing Record 23 of Set 8 | skjervoy
# Processing Record 24 of Set 8 | guarapuava
# Processing Record 25 of Set 8 | sisimiut
# Processing Record 26 of Set 8 | fuerte olimpo
# Processing Record 27 of Set 8 | los llanos de aridane
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | shu
# Processing Record 30 of Set 8 | henties bay
# Processing Record 31 of Set 8 | mehamn
# Processing Record 32 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 8 | fort-shevchenko
# Processing Record 34 of Set 8 | penzance
# Processing Record 35 of Set 8 | kampot
# Processing Record 36 of Set 8 | roseland
# Processing Record 37 of Set 8 | ostrovnoy
# Processing Record 38 of Set 8 | muscle shoals
# Processing Record 39 of Set 8 | nabire
# Processing Record 40 of Set 8 | hervey bay
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | bonavista
# Processing Record 43 of Set 8 | boguchany
# Processing Record 44 of Set 8 | ust-kuyga
# Processing Record 45 of Set 8 | casian
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | makung
# City not found. Skipping...
# Processing Record 48 of Set 8 | shar
# Processing Record 49 of Set 8 | lac du bonnet
# Processing Record 50 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 9 | grootfontein
# Processing Record 2 of Set 9 | hasaki
# Processing Record 3 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 9 | santa marta
# Processing Record 5 of Set 9 | abnub
# Processing Record 6 of Set 9 | sao francisco
# Processing Record 7 of Set 9 | ljaskovec
# City not found. Skipping...
# Processing Record 8 of Set 9 | marsa matruh
# Processing Record 9 of Set 9 | hegang
# Processing Record 10 of Set 9 | port augusta
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | magadan
# Processing Record 13 of Set 9 | santa isabel do rio negro
# Processing Record 14 of Set 9 | sinnamary
# Processing Record 15 of Set 9 | alice springs
# Processing Record 16 of Set 9 | vanimo
# Processing Record 17 of Set 9 | sao jose da coroa grande
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | medgyesegyhaza
# Processing Record 20 of Set 9 | arak
# Processing Record 21 of Set 9 | megion
# Processing Record 22 of Set 9 | picton
# Processing Record 23 of Set 9 | leningradskiy
# Processing Record 24 of Set 9 | marostica
# Processing Record 25 of Set 9 | inuvik
# Processing Record 26 of Set 9 | maridi
# Processing Record 27 of Set 9 | san quintin
# Processing Record 28 of Set 9 | tandalti
# Processing Record 29 of Set 9 | kisangani
# Processing Record 30 of Set 9 | bolivar
# Processing Record 31 of Set 9 | bathsheba
# Processing Record 32 of Set 9 | srednekolymsk
# Processing Record 33 of Set 9 | masuda
# Processing Record 34 of Set 9 | qasigiannguit
# Processing Record 35 of Set 9 | tashara
# Processing Record 36 of Set 9 | alyangula
# Processing Record 37 of Set 9 | ikalamavony
# Processing Record 38 of Set 9 | luba
# Processing Record 39 of Set 9 | aksu
# Processing Record 40 of Set 9 | korla
# Processing Record 41 of Set 9 | el copey
# Processing Record 42 of Set 9 | andros town
# Processing Record 43 of Set 9 | rosa zarate
# Processing Record 44 of Set 9 | bucerias
# Processing Record 45 of Set 9 | tsaratanana
# Processing Record 46 of Set 9 | esmeraldas
# Processing Record 47 of Set 9 | tahta
# Processing Record 48 of Set 9 | pala
# Processing Record 49 of Set 9 | cayenne
# Processing Record 50 of Set 9 | florianopolis
# Processing Record 1 of Set 10 | presidente prudente
# Processing Record 2 of Set 10 | slave lake
# Processing Record 3 of Set 10 | port shepstone
# Processing Record 4 of Set 10 | machacamarca
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | fochville
# Processing Record 7 of Set 10 | kaeo
# Processing Record 8 of Set 10 | sibolga
# Processing Record 9 of Set 10 | okhotsk
# Processing Record 10 of Set 10 | nova vodolaha
# Processing Record 11 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 12 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 10 | ambulu
# Processing Record 14 of Set 10 | katsuura
# Processing Record 15 of Set 10 | atar
# Processing Record 16 of Set 10 | radhanpur
# Processing Record 17 of Set 10 | arkhipo-osipovka
# Processing Record 18 of Set 10 | fomboni
# Processing Record 19 of Set 10 | tommot
# Processing Record 20 of Set 10 | fuyu
# Processing Record 21 of Set 10 | clonakilty
# Processing Record 22 of Set 10 | troitsko-pechorsk
# Processing Record 23 of Set 10 | buchanan
# Processing Record 24 of Set 10 | kayes
# Processing Record 25 of Set 10 | sri aman
# Processing Record 26 of Set 10 | nesbyen
# Processing Record 27 of Set 10 | aripuana
# Processing Record 28 of Set 10 | brightwater
# Processing Record 29 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 10 | manali
# Processing Record 31 of Set 10 | contai
# Processing Record 32 of Set 10 | vao
# Processing Record 33 of Set 10 | pisco
# Processing Record 34 of Set 10 | nyuksenitsa
# Processing Record 35 of Set 10 | quatre cocos
# Processing Record 36 of Set 10 | constitucion
# Processing Record 37 of Set 10 | dutse
# Processing Record 38 of Set 10 | nador
# Processing Record 39 of Set 10 | port moresby
# Processing Record 40 of Set 10 | pillaro
# Processing Record 41 of Set 10 | abha
# Processing Record 42 of Set 10 | mangai
# Processing Record 43 of Set 10 | ambilobe
# Processing Record 44 of Set 10 | kargil
# Processing Record 45 of Set 10 | canutama
# Processing Record 46 of Set 10 | banda aceh
# Processing Record 47 of Set 10 | salalah
# Processing Record 48 of Set 10 | kalmunai
# Processing Record 49 of Set 10 | geraldton
# Processing Record 50 of Set 10 | boissevain
# Processing Record 1 of Set 11 | charleston
# Processing Record 2 of Set 11 | quang ngai
# Processing Record 3 of Set 11 | alanya
# Processing Record 4 of Set 11 | kapuskasing
# Processing Record 5 of Set 11 | pokhara
# Processing Record 6 of Set 11 | ust-omchug
# Processing Record 7 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 8 of Set 11 | ust-tsilma
# Processing Record 9 of Set 11 | teruel
# Processing Record 10 of Set 11 | caribou
# Processing Record 11 of Set 11 | grand haven
# Processing Record 12 of Set 11 | mankono
# Processing Record 13 of Set 11 | le port
# Processing Record 14 of Set 11 | nuziders
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | conceicao do araguaia
# Processing Record 18 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 11 | bubaque
# Processing Record 21 of Set 11 | rosetta
# Processing Record 22 of Set 11 | svetlyy
# Processing Record 23 of Set 11 | taonan
# Processing Record 24 of Set 11 | capinzal
# Processing Record 25 of Set 11 | west wendover
# Processing Record 26 of Set 11 | huzhou
# Processing Record 27 of Set 11 | kiunga
# Processing Record 28 of Set 11 | takaka
# Processing Record 29 of Set 11 | rawson
# Processing Record 30 of Set 11 | jutai
# Processing Record 31 of Set 11 | san policarpo
# Processing Record 32 of Set 11 | broome
# Processing Record 33 of Set 11 | fasa
# Processing Record 34 of Set 11 | mian channun
# Processing Record 35 of Set 11 | ballsh
# Processing Record 36 of Set 11 | moron
# Processing Record 37 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 11 | cumra
# Processing Record 39 of Set 11 | taiyuan
# Processing Record 40 of Set 11 | avera
# Processing Record 41 of Set 11 | bandundu
# Processing Record 42 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 11 | kavieng
# Processing Record 44 of Set 11 | cururupu
# Processing Record 45 of Set 11 | clovis
# Processing Record 46 of Set 11 | aykhal
# Processing Record 47 of Set 11 | yuancheng
# Processing Record 48 of Set 11 | amapa
# Processing Record 49 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 11 | camapua
# Processing Record 1 of Set 12 | muros
# Processing Record 2 of Set 12 | mutis
# Processing Record 3 of Set 12 | tigil
# Processing Record 4 of Set 12 | san martin
# Processing Record 5 of Set 12 | pundaguitan
# Processing Record 6 of Set 12 | kolyshley
# Processing Record 7 of Set 12 | olafsvik
# Processing Record 8 of Set 12 | qui nhon
# Processing Record 9 of Set 12 | puerto del rosario
# Processing Record 10 of Set 12 | talara
# Processing Record 11 of Set 12 | makaha
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | zhezkazgan
# Processing Record 14 of Set 12 | ancud
# Processing Record 15 of Set 12 | chabahar
# Processing Record 16 of Set 12 | varhaug
# Processing Record 17 of Set 12 | gamba
# Processing Record 18 of Set 12 | heilbron
# Processing Record 19 of Set 12 | acapulco
# Processing Record 20 of Set 12 | brigantine
# Processing Record 21 of Set 12 | rosarito
# Processing Record 22 of Set 12 | hami
# Processing Record 23 of Set 12 | deputatskiy
# Processing Record 24 of Set 12 | port-gentil
# Processing Record 25 of Set 12 | karagay
# Processing Record 26 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 12 | amahai
# Processing Record 28 of Set 12 | moussoro
# Processing Record 29 of Set 12 | cravo norte
# Processing Record 30 of Set 12 | turukhansk
# Processing Record 31 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 12 | okha
# Processing Record 33 of Set 12 | tabou
# Processing Record 34 of Set 12 | floro
# Processing Record 35 of Set 12 | campoverde
# Processing Record 36 of Set 12 | coihaique
# Processing Record 37 of Set 12 | saryg-sep
# Processing Record 38 of Set 12 | hamilton
# Processing Record 39 of Set 12 | aberfeldy
# Processing Record 40 of Set 12 | smithers
# Processing Record 41 of Set 12 | bisert
# Processing Record 42 of Set 12 | guapi
# Processing Record 43 of Set 12 | ocampo
# Processing Record 44 of Set 12 | guerrero negro
# Processing Record 45 of Set 12 | goderich
# Processing Record 46 of Set 12 | san lorenzo
# Processing Record 47 of Set 12 | usinsk
# Processing Record 48 of Set 12 | lorengau
# Processing Record 49 of Set 12 | uetersen
# Processing Record 50 of Set 12 | farroupilha
# Processing Record 1 of Set 13 | neiafu
# Processing Record 2 of Set 13 | port macquarie
# Processing Record 3 of Set 13 | duiwelskloof
# Processing Record 4 of Set 13 | vitim
# Processing Record 5 of Set 13 | malente
# Processing Record 6 of Set 13 | latung
# Processing Record 7 of Set 13 | zhangjiakou
# Processing Record 8 of Set 13 | aswan
# Processing Record 9 of Set 13 | malakal
# Processing Record 10 of Set 13 | road town
# Processing Record 11 of Set 13 | iquique
# Processing Record 12 of Set 13 | broken hill
# Processing Record 13 of Set 13 | belmonte
# Processing Record 14 of Set 13 | northam
# Processing Record 15 of Set 13 | oyon
# Processing Record 16 of Set 13 | bayji
# Processing Record 17 of Set 13 | toamasina
# Processing Record 18 of Set 13 | sobolevo
# Processing Record 19 of Set 13 | la macarena
# Processing Record 20 of Set 13 | evanston
# Processing Record 21 of Set 13 | dakar
# Processing Record 22 of Set 13 | dancheng
# Processing Record 23 of Set 13 | sampit
# Processing Record 24 of Set 13 | diego de almagro
# Processing Record 25 of Set 13 | kattivakkam
# Processing Record 26 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 27 of Set 13 | atasu
# Processing Record 28 of Set 13 | vostok
# Processing Record 29 of Set 13 | marsh harbour
# Processing Record 30 of Set 13 | camacha
# Processing Record 31 of Set 13 | svetlogorsk
# Processing Record 32 of Set 13 | medea
# Processing Record 33 of Set 13 | opuwo
# Processing Record 34 of Set 13 | nelson bay
# Processing Record 35 of Set 13 | leshukonskoye
# Processing Record 36 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 13 | zolotukhino
# Processing Record 38 of Set 13 | aracati
# Processing Record 39 of Set 13 | jacqueville
# Processing Record 40 of Set 13 | tessalit
# Processing Record 41 of Set 13 | chesma
# Processing Record 42 of Set 13 | independence
# Processing Record 43 of Set 13 | snezhnogorsk
# Processing Record 44 of Set 13 | kysyl-syr
# Processing Record 45 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 46 of Set 13 | mingaora
# Processing Record 47 of Set 13 | buraydah
# Processing Record 48 of Set 13 | ouesso
# Processing Record 49 of Set 13 | tuatapere
# Processing Record 50 of Set 13 | el mante
# Processing Record 1 of Set 14 | huntington
# Processing Record 2 of Set 14 | pahrump
# Processing Record 3 of Set 14 | skovde
# City not found. Skipping...
# Processing Record 4 of Set 14 | don sak
# Processing Record 5 of Set 14 | lomovka
# Processing Record 6 of Set 14 | seoul
# Processing Record 7 of Set 14 | lucea
# Processing Record 8 of Set 14 | tangwani
# Processing Record 9 of Set 14 | bowen
# Processing Record 10 of Set 14 | itambacuri
# Processing Record 11 of Set 14 | udachnyy
# Processing Record 12 of Set 14 | mwinilunga
# Processing Record 13 of Set 14 | puerto madryn
# Processing Record 14 of Set 14 | benguela
# Processing Record 15 of Set 14 | ca mau
# Processing Record 16 of Set 14 | bilibino
# Processing Record 17 of Set 14 | sioux lookout
# Processing Record 18 of Set 14 | tolaga bay
# Processing Record 19 of Set 14 | abilene
# Processing Record 20 of Set 14 | matale
# Processing Record 21 of Set 14 | sangar
# Processing Record 22 of Set 14 | kruisfontein
# Processing Record 23 of Set 14 | krasnoselkup
# Processing Record 24 of Set 14 | fairbanks
# Processing Record 25 of Set 14 | nalut
# Processing Record 26 of Set 14 | san joaquin
# Processing Record 27 of Set 14 | charters towers
# Processing Record 28 of Set 14 | nome
# Processing Record 29 of Set 14 | bela
# Processing Record 30 of Set 14 | dwarka
# Processing Record 31 of Set 14 | santa ana
# Processing Record 32 of Set 14 | kurtalan
# Processing Record 33 of Set 14 | tairua
# Processing Record 34 of Set 14 | madang
# Processing Record 35 of Set 14 | karatau
# Processing Record 36 of Set 14 | saldanha
# Processing Record 37 of Set 14 | xapuri
# Processing Record 38 of Set 14 | yumen
# Processing Record 39 of Set 14 | anadyr
# Processing Record 40 of Set 14 | ponta delgada
# Processing Record 41 of Set 14 | mahanoro
# Processing Record 42 of Set 14 | ust-nera
# Processing Record 43 of Set 14 | joensuu
# Processing Record 44 of Set 14 | aborlan
# Processing Record 45 of Set 14 | vanavara
# Processing Record 46 of Set 14 | tottori
# Processing Record 47 of Set 14 | aklavik
# Processing Record 48 of Set 14 | puerto el triunfo
# Processing Record 49 of Set 14 | nouadhibou
# Processing Record 50 of Set 14 | kudahuvadhoo
# Processing Record 1 of Set 15 | kangaatsiaq
# Processing Record 2 of Set 15 | tiznit
# Processing Record 3 of Set 15 | verkhnyaya inta
# Processing Record 4 of Set 15 | surat
# Processing Record 5 of Set 15 | mo i rana
# Processing Record 6 of Set 15 | kieta
# Processing Record 7 of Set 15 | anloga
# Processing Record 8 of Set 15 | vuktyl
# Processing Record 9 of Set 15 | abyek
# Processing Record 10 of Set 15 | bonwapitse
# Processing Record 11 of Set 15 | vilhena
# Processing Record 12 of Set 15 | mwembe
# Processing Record 13 of Set 15 | akdagmadeni
# Processing Record 14 of Set 15 | marzuq
# Processing Record 15 of Set 15 | ilhabela
# Processing Record 16 of Set 15 | camabatela
# Processing Record 17 of Set 15 | lagos
# Processing Record 18 of Set 15 | panixtlahuaca
# City not found. Skipping...
# Processing Record 19 of Set 15 | nemuro
# Processing Record 20 of Set 15 | cukai
# Processing Record 21 of Set 15 | itapuranga
# Processing Record 22 of Set 15 | hecun
# Processing Record 23 of Set 15 | ishigaki
# Processing Record 24 of Set 15 | adre
# Processing Record 25 of Set 15 | moyuta
# Processing Record 26 of Set 15 | shahreza
# Processing Record 27 of Set 15 | izhma
# Processing Record 28 of Set 15 | pagman
# City not found. Skipping...
# Processing Record 29 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 15 | heishan
# Processing Record 31 of Set 15 | great yarmouth
# Processing Record 32 of Set 15 | praia
# Processing Record 33 of Set 15 | beyneu
# Processing Record 34 of Set 15 | taikang
# Processing Record 35 of Set 15 | anamur
# Processing Record 36 of Set 15 | zhuhai
# Processing Record 37 of Set 15 | mangrol
# Processing Record 38 of Set 15 | erzurum
# Processing Record 39 of Set 15 | te anau
# Processing Record 40 of Set 15 | bayir
# Processing Record 41 of Set 15 | yatou
# Processing Record 42 of Set 15 | elizabeth city
# Processing Record 43 of Set 15 | jaciara
# Processing Record 44 of Set 15 | kathmandu
# Processing Record 45 of Set 15 | ayer itam
# City not found. Skipping...
# Processing Record 46 of Set 15 | matamoros
# Processing Record 47 of Set 15 | huamachuco
# Processing Record 48 of Set 15 | biak
# Processing Record 49 of Set 15 | edd
# Processing Record 50 of Set 15 | flin flon
# Processing Record 1 of Set 16 | bonfim
# Processing Record 2 of Set 16 | vila velha
# Processing Record 3 of Set 16 | ostersund
# Processing Record 4 of Set 16 | mpika
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#            City Country               Date      Lat       Lng  Max Temp  \
# 682   Kathmandu      NP  22-05-07 03:37:54  27.7167   85.3167     75.42
# 683   Matamoros      MX  22-05-07 03:38:53  25.5333 -103.2500     89.71
# 684  Huamachuco      PE  22-05-07 03:38:54  -7.8000  -78.0667     48.29
# 685        Biak      ID  22-05-07 03:38:54  -0.9131  122.8766     82.74
# 686         Edd      ER  22-05-07 03:38:55  13.9297   41.6925     83.91
# 687   Flin Flon      CA  22-05-07 03:38:55  54.7682 -101.8650     48.65
# 688      Bonfim      BR  22-05-07 03:39:56   3.0833  -59.9500     78.98
# 689  Vila Velha      BR  22-05-07 03:39:48 -20.3297  -40.2925     75.15
# 690   Ostersund      SE  22-05-07 03:39:57  63.1792   14.6357     38.61
# 691       Mpika      ZM  22-05-07 03:39:57 -11.8343   31.4529     55.74
#
#      Min Temp  Humidity  Cloudiness  Wind Speed Current Description
# 682     75.42        60          40        3.44    scattered clouds
# 683     89.71        17           0        6.91           clear sky
# 684     48.29        91          44        3.58    scattered clouds
# 685     82.74        77          84        1.10       broken clouds
# 686     83.91        76           7        4.79           clear sky
# 687     48.65        92          94       12.80     overcast clouds
# 688     78.98        81         100        1.68       moderate rain
# 689     75.15        78           0        9.22           clear sky
# 690     37.85        75          75       16.11       broken clouds
# 691     55.74        97          39        4.72    scattered clouds

# %%
sort = city_data_df.groupby(['Country'])['City'].count().sort_values(ascending=False)
sort.head(20)
# Out:
# Country
# RU    80
# US    56
# BR    46
# CA    29
# AU    28
# CN    25
# IN    23
# ID    19
# ZA    15
# NZ    15
# NO    14
# JP    14
# AR    14
# MX    12
# PH    11
# KZ    10
# CO    10
# GL    10
# PT    10
# GB     9
# Name: City, dtype: int64

# %%
# # Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# # Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
